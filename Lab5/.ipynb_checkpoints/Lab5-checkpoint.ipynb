# %% [markdown]
# # <p style="text-align: center;">EE 379K: Data Science Lab</p>
# # <p style="text-align: center;">Lab 4 - 10/9/17</p>
# ## <p style="text-align: center;">Rachel Chen and Kevin Yee</p>
# ### <p style="text-align: center;"> rjc2737 and kjy252</p>

# %% [markdown]
# Book: http://www-bcf.usc.edu/~gareth/ISL/ISLR%20First%20Printing.pdf
#
# Website: http://www-bcf.usc.edu/~gareth/ISL/
#
# Fischer's Linear Discriminant http://research.cs.tamu.edu/prism/lectures/pr/pr_l10.pdf

# %% [markdown]
# ## Problem 1
#
# ![](http://i.markdownnotes.com/image_6CFQDap.jpg)

# %% [markdown]
# ## 1.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as mpatches
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
# %matplotlib inline

# %%
###  Part 1 - Generating Points ###
u1 = [0, 0, 0]
covMatrix1 = [[1, 0.9, 0.9], [0.9, 1, 0.9], [0.9, 0.9, 1]]

u2 = [0, 0, 1]
covMatrix2 = [[1, 0.8, 0.8], [0.8, 1, 0.8], [0.8, 0.8, 1]]

#generate 20 random points from a Gaussian multivariate distribution
x1, y1, z1 = np.random.multivariate_normal(u1, covMatrix1, 20).T
x2, y2, z2 = np.random.multivariate_normal(u2, covMatrix2, 20).T

#labels 
labels1 = [1 for x in range(20)]
labels2 = [2 for x in range(20)]
labels = labels1 + labels2

#stack columns
C1 = np.column_stack((x1,y1,z1))
C2 = np.column_stack((x2,y2,z2))
C = np.vstack((C1,C2))

#plot the 3D plot of the clouds of data points
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x1, y1, z1, c='r', marker='o')
ax.scatter(x2, y2, z2, c='b', marker='o')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')

red_patch = mpatches.Patch(color='red', label='label1')
blue_patch = mpatches.Patch(color='blue', label='label2')
plt.legend(handles=[red_patch, blue_patch])

plt.show()

# %% [markdown]
# ### Step 1:
#
# Find Between Scatter plot Matrix
# $$\delta_b = ( \mu_1 - \mu_0)(\mu_1 - \mu_0)^T$$
#
# Find In Class Scatter Matrix $\delta_w$
#
# Where:
# $$\delta_w = \sum_{X_i \subset C0} (X_i - \mu_0)(X_i- \mu_0)^T + \sum_{X_i \subset C1} (X_i - \mu_1)(X_i- \mu_1)^T$$

# %%
from collections import OrderedDict

###  Part 2 Calculate Fischer's LDA ###
scatter1 = 0
scatter2 = 0

u1 = np.asarray(u1)
u2 = np.asarray(u2)

# Calcalate Between Scatter Plot Matrx
Sb = np.dot((u1-u2).reshape(3,1),(np.transpose((u1-u2).reshape(3,1))))

#Caculate Class Scatter Matrix
for i in range(20):
    scatter1 += np.dot((C1[i] - u1).reshape(3,1),np.transpose((C1[i] - u1).reshape(3,1))) 
    scatter2 += np.dot((C2[i]- u2).reshape(3,1),np.transpose((C2[i] - u2).reshape(3,1)))
Sw = scatter1 + scatter2


#Calculate Fischers's Coefficients
eig_vals, eig_vecs  = np.linalg.eig(np.linalg.inv(Sw).dot(Sb))

for i in range(len(eig_vals)):
    eigvec_sc = eig_vecs[:,i].reshape(3,1)   
    print('\nEigenvector {}: \n{}'.format(i+1, eigvec_sc.real))
    print('Eigenvalue {:}: {:.2e}'.format(i+1, eig_vals[i].real))


# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs = sorted(eig_pairs, key=lambda k: k[0], reverse=True)

# Visually confirm that the list is correctly sorted by decreasing eigenvalues
print('Eigenvalues in decreasing order:\n')
for i in eig_pairs:
    print(i[0])
    
print('Variance explained:\n')
eigv_sum = sum(eig_vals)
for i,j in enumerate(eig_pairs):
    print('eigenvalue {0:}: {1:.2%}'.format(i+1, (j[0]/eigv_sum).real))

#Take the first eigenvector since it explains the highest variance
W = eig_pairs[0][1].reshape(3,1)

#project the points downwards 
C_lda = C.dot(W)

#plt pts with fischer
plt.figure(figsize=(20,6))
plt.subplot(121)
plt.title('LDA using Fischers')
plt.eventplot(C_lda[:20], orientation='horizontal', colors='r', label = 'label1')
plt.eventplot(C_lda[20:], orientation='horizontal', colors='b', label = 'label2')


###  Part 3 Compare with LDA ###

# Use LDA to compare
clf = LDA()
clf.fit(C, labels)
s1_new = clf.transform(C[:20])
s2_new = clf.transform(C[20:40])

# Plot the results
plt.subplot(122)
plt.title('LDA using Sklearn')
plt.eventplot(s1_new, orientation='horizontal', colors='r', label = 'label1')
plt.eventplot(s2_new, orientation='horizontal', colors='b', label = 'label2')
# Out:
# Eigenvector 1:
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# Eigenvalue 1: 0.00e+00
#
# Eigenvector 2:
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# Eigenvalue 2: 0.00e+00
#
# Eigenvector 3:
# [[-0.6005212 ]
#  [-0.17731482]
#  [ 0.77970106]]
# Eigenvalue 3: 1.44e-01
# Eigenvalues in decreasing order:
#
# 0.144333428322
# 0.0
# 0.0
# Variance explained:
#
# eigenvalue 1: 100.00%
# eigenvalue 2: 0.00%
# eigenvalue 3: 0.00%
# ...

# %% [markdown]
# ##Problem 2.
# Problem 10 from Chapter 4 (Classification for the ‘weekly’ dataset) Read the chapter
# to figure out how to use KNN and QDA, as we did not discuss these in class.
#
# ![](http://i.markdownnotes.com/image_tvUnpbf.jpg)

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn.linear_model as skl_lm
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.metrics import confusion_matrix, classification_report, precision_score
from sklearn import preprocessing
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.cross_validation import train_test_split, LeaveOneOut 

import statsmodels.api as sm
import statsmodels.formula.api as smf

pd.set_option('display.notebook_repr_html', False)

# %matplotlib inline
plt.style.use('seaborn-white')
from sklearn.linear_model import LogisticRegression
from pandas.plotting import scatter_matrix
 


pd.set_option('display.notebook_repr_html', False)

# %matplotlib inline
plt.style.use('seaborn-white')

# %%
df = pd.read_csv('Data/Weekly.csv')
print df.head()
sns.pairplot(df);
sns.plt.show();
# Out:
#    Unnamed: 0  Year   Lag1   Lag2   Lag3   Lag4   Lag5    Volume  Today  \
# 0           1  1990  0.816  1.572 -3.936 -0.229 -3.484  0.154976 -0.270
# 1           2  1990 -0.270  0.816  1.572 -3.936 -0.229  0.148574 -2.576
# 2           3  1990 -2.576 -0.270  0.816  1.572 -3.936  0.159837  3.514
# 3           4  1990  3.514 -2.576 -0.270  0.816  1.572  0.161630  0.712
# 4           5  1990  0.712  3.514 -2.576 -0.270  0.816  0.153728  1.178
#
#   Direction
# 0      Down
# 1      Down
# 2        Up
# 3        Up
# 4        Up

# %% [markdown]
# ### Observation of Trends
#
# 1. Volume appears to be the only value correlated to Year

# %% [markdown]
# ### 2(b)
# Use the full data set to perform a logistic regression with Direction as the response and the five lag variables plus Volume as predictors. Use the summary function to print the results. Do any of the predictors appear to be statistically significant? If so, which ones?

# %%
X = df.loc[:,'Year':'Today']
y = df.Direction
y = y.replace("Down",1)
y = y.replace("Up",0)

# %%
logistic_model = (smf.glm(formula='Direction ~ Lag1 + Lag2 + Lag3 + Lag4 + Lag5 + Volume',
                                       data=df,
                                       family=sm.families.Binomial())
                               .fit())
logistic_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           Generalized Linear Model Regression Results
# ...
# Dep. Variable:     ['Direction[Down]', 'Direction[Up]']   No. Observations:                 1089
# Model:                                              GLM   Df Residuals:                     1082
# Model Family:                                  Binomial   Df Model:                            6
# Link Function:                                    logit   Scale:                             1.0
# Method:                                            IRLS   Log-Likelihood:                -743.18
# Date:                                  Thu, 05 Oct 2017   Deviance:                       1486.4
# Time:                                          10:53:46   Pearson chi2:                 1.09e+03
# No. Iterations:                                       4
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# We define stastical significance with a value's z score under 0.05. The only observable value with z-score under 0.05 is Lag2.

# %% [markdown]
# ## 2(c)
# Compute the confusion matrix and overall fraction of correct predictions. Regard value “Down” as the positive class. Calculate the sensitivity and specificity according to the confusion matrix.
#
# https://en.wikipedia.org/wiki/Confusion_matrix
#
# Note, my confusion matrix prints out as the following:
#
# ![](http://i.markdownnotes.com/image_QI3KoAL.png)

# %%
pred = logistic_model.predict(X)

print('{}\n Logisitic Regression with entire data set :\n'.format('*' * 80))
print "Confusion Matrix:\n"
print confusion_matrix(y,pred.round()).T
print "\n"

print "Confusion Summary:\n"
print pd.crosstab(y,pred.round(), rownames=['True'], colnames=['Predicted'], margins=True)
print "\n"

print "Classification Report:\n"
print(classification_report(y,pred.round()))
# Out:
# ********************************************************************************
#  Logisitic Regression with entire data set :
#
# Confusion Matrix:
#
# [[557 430]
#  [ 48  54]]
#
#
# Confusion Summary:
#
# Predicted  0.0  1.0   All
# True
# 0          557   48   605
# 1          430   54   484
# All        987  102  1089
#
#
# Classification Report:
#
#              precision    recall  f1-score   support
#
#           0       0.56      0.92      0.70       605
#           1       0.53      0.11      0.18       484
#
# avg / total       0.55      0.56      0.47      1089

# %% [markdown]
# ## 2(d)
# Now fit the logistic regression model using a training data period from 1990 to 2008, with Lag2 as the only predictor. Compute the confusion matrix and the overall fraction of correct predictions for the held out data (that is, the data from 2009 and 2010).

# %%
X1990 = df[df['Year']<=2008].replace("Down",1).replace("Up",0)
X2009 = df[df['Year']>2008].replace("Down",1).replace("Up",0)


X_train = X1990.Lag2
y_train = X1990.Direction

X_test = X2009.Lag2
y_test = X2009.Direction

log_reg = LogisticRegression()
log_reg.fit(X_train.reshape(-1,1),y_train)
pred = log_reg.predict(X_test.reshape(-1,1))


print('{}\n Logisitic Regression with just Lag2 :\n'.format('*' * 80))
print("Confusion Matrix Summary:")
print pd.crosstab(y_test,pred.round(), rownames=['True'], colnames=['Predicted'], margins=True)
print("Classification Report:")
print(classification_report(y_test,pred.round()))
# Out:
# ********************************************************************************
#  Logisitic Regression with just Lag2 :
#
# Confusion Matrix Summary:
# Predicted   0   1  All
# True
# 0          56   5   61
# 1          34   9   43
# All        90  14  104
# Classification Report:
#              precision    recall  f1-score   support
#
#           0       0.62      0.92      0.74        61
#           1       0.64      0.21      0.32        43
#
# avg / total       0.63      0.62      0.57       104

# %% [markdown]
# ## 2(e) Repeat (d) using LDA.

# %% [markdown]
# Linear Discriminant Analysis (LDA) is actually a classification algorithm, but during training it learns the most discriminative axes between the classes, and these axes can then be used to define a hyperplane onto which to project the data. The benefit is that the projection will keep classes as far apart as possible, so LDA is a good technique to reduce dimensionality before running another classification algorithm such as an SVM classifier.

# %%
lda = LDA()
lda.fit(X_train.reshape(-1,1),y_train)
lda_pred = lda.predict(X_test.reshape(-1,1))

print('{}\n LDA with Lag2 :\n'.format('*' * 80))
print("Confusion Matrix:")
print pd.crosstab(y_test,lda_pred.round(), rownames=['True'], colnames=['Predicted'], margins=True)
print("Classification Report:")
print(classification_report(y_test,lda_pred.round()))
# Out:
# ********************************************************************************
#  LDA with Lag2 :
#
# Confusion Matrix:
# Predicted   0   1  All
# True
# 0          56   5   61
# 1          34   9   43
# All        90  14  104
# Classification Report:
#              precision    recall  f1-score   support
#
#           0       0.62      0.92      0.74        61
#           1       0.64      0.21      0.32        43
#
# avg / total       0.63      0.62      0.57       104

# %% [markdown]
# ## 2(f) Repeat (d) using QDA.

# %%
qda = QDA()
qda.fit(X_train.reshape(-1,1),y_train)
qda_pred = qda.predict(X_test.reshape(-1,1))

print('{}\n QDA with Lag2 :\n'.format('*' * 80))
print("Confusion Matrix:")
print confusion_matrix(y_test,qda_pred)
print pd.crosstab(y_test,qda_pred.round(), rownames=['True'], colnames=['Predicted'], margins=True)
print("Classification Report")
print(classification_report(y_test,qda_pred))
# Out:
# ********************************************************************************
#  QDA with Lag2 :
#
# Confusion Matrix:
# [[61  0]
#  [43  0]]
# Predicted    0  All
# True
# 0           61   61
# 1           43   43
# All        104  104
# Classification Report
#              precision    recall  f1-score   support
#
#           0       0.59      1.00      0.74        61
#           1       0.00      0.00      0.00        43
#
# avg / total       0.34      0.59      0.43       104

# %% [markdown]
# ## 2(g) Repeat (d) using KNN

# %%
knn1 = KNN(n_neighbors=1)
knn1.fit(X_train.reshape(-1,1),y_train)
knn_pred = knn1.predict(X_test.reshape(-1,1))
print pd.crosstab(y_test,knn_pred.round(), rownames=['True'], colnames=['Predicted'], margins=True)
print(classification_report(y_test,knn_pred.round()))
# Out:
# Predicted   0   1  All
# True
# 0          30  31   61
# 1          22  21   43
# All        52  52  104
#              precision    recall  f1-score   support
#
#           0       0.58      0.49      0.53        61
#           1       0.40      0.49      0.44        43
#
# avg / total       0.51      0.49      0.49       104

# %% [markdown]
# ## Problem 3.
# Problem 5 from Chapter 5 Estimating the test error of logistic regression using a
# validation set.
#
# ![](http://i.markdownnotes.com/image_tE482Hl.png)
# ![](http://i.markdownnotes.com/image_vrk7zl2.png)

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn.linear_model as skl_lm
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
from sklearn.metrics import confusion_matrix, classification_report, precision_score
from sklearn import preprocessing
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.cross_validation import train_test_split, LeaveOneOut 

import statsmodels.api as sm
import statsmodels.formula.api as smf

pd.set_option('display.notebook_repr_html', False)

# %matplotlib inline
plt.style.use('seaborn-white')
from sklearn.linear_model import LogisticRegression
from pandas.plotting import scatter_matrix
import statsmodels.api as sm
import statsmodels.formula.api as smf


pd.set_option('display.notebook_repr_html', False)

# %matplotlib inline
plt.style.use('seaborn-white')

# %%
default = pd.read_csv("Data/default.csv")
default.head()
# Out:
#    Unnamed: 0 default student      balance        income
# 0           1      No      No   729.526495  44361.625074
# 1           2      No     Yes   817.180407  12106.134700
# 2           3      No      No  1073.549164  31767.138947
# 3           4      No      No   529.250605  35704.493935
# 4           5      No      No   785.655883  38463.495879

# %%
# predict default with just income and balance 
X = default.loc[:,"balance":"income"]
y = default.default
y = y.replace('No',0).replace('Yes',1)
log_reg = LogisticRegression()
log_reg.fit(X,y)
pred = log_reg.predict(X)

print pd.crosstab(y,pred.round(), rownames=['True'], colnames=['Predicted'], margins=True)


print classification_report(y,pred.round())
# Out:
# Predicted     0  1    All
# True
# 0          9664  3   9667
# 1           333  0    333
# All        9997  3  10000
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      9667
#           1       0.00      0.00      0.00       333
#
# avg / total       0.93      0.97      0.95     10000

# %%
# test train split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25, random_state=10)

log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
pred = log_reg.predict(X_test)
accuracy = accuracy_score(y_test,pred)
valError = 1 - accuracy

print "75% Training Set, 25% Testing Set"
print "Accuracy: " + str((accuracy *100))
print "Validation Error: " + str(valError*100)


X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.50, random_state=10)

log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
pred = log_reg.predict(X_test)
accuracy = accuracy_score(y_test,pred)
valError = 1 - accuracy


print "50% Training Set, 50% Testing Set"
print "Accuracy: " + str((accuracy *100))
print "Validation Error: " + str(valError*100)


X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.75, random_state=10)

log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
pred = log_reg.predict(X_test)
accuracy = accuracy_score(y_test,pred)
valError = 1 - accuracy

print "25% Training Set, 75% Testing Set"
print "Accuracy: " + str((accuracy *100))
print "Validation Error: " + str(valError*100)


X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.90, random_state=10)

log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
pred = log_reg.predict(X_test)
accuracy = accuracy_score(y_test,pred)
valError = 1 - accuracy

print "10% Training Set, 90% Testing Set"
print "Accuracy: " + str((accuracy *100))
print "Validation Error: " + str(valError*100)
# Out:
# 75% Training Set, 25% Testing Set
# Accuracy: 96.28
# Validation Error: 3.72
# 50% Training Set, 50% Testing Set
# Accuracy: 96.7
# Validation Error: 3.3
# 25% Training Set, 75% Testing Set
# Accuracy: 96.68
# Validation Error: 3.32
# 10% Training Set, 90% Testing Set
# Accuracy: 96.5777777778
# Validation Error: 3.42222222222

# %%
X = default.loc[:,"student":"income"]
X = X.replace("No",0).replace("Yes",1)

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25, random_state=10)

log_reg = LogisticRegression()
log_reg.fit(X_train,y_train)
pred = log_reg.predict(X_test)
accuracy = accuracy_score(y_test,pred)
valError = 1 - accuracy

print "75% Training Set, 25% Testing Set"
print "Accuracy: " + str((accuracy *100))
print "Validation Error: " + str(valError*100)
# Out:
# 75% Training Set, 25% Testing Set
# Accuracy: 96.28
# Validation Error: 3.72

# %% [markdown]
# ## Problem 4:
# Problem 8 from Chapter 5.(Cross Validation). Use Google or any other means to find
# the Python counterpart to R’s rnorm.)
#
# ![](http://i.markdownnotes.com/image_OhVmZdh.png)
# ![](http://i.markdownnotes.com/image_4g7pr54.png)

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn.linear_model as skl_lm
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
from sklearn.metrics import confusion_matrix, classification_report, precision_score
from sklearn import preprocessing
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.cross_validation import train_test_split, LeaveOneOut, KFold, cross_val_score

import statsmodels.api as sm
import statsmodels.formula.api as smf

pd.set_option('display.notebook_repr_html', False)

# %matplotlib inline
plt.style.use('seaborn-white')
from sklearn.linear_model import LogisticRegression
from pandas.plotting import scatter_matrix
import statsmodels.api as sm
import statsmodels.formula.api as smf


pd.set_option('display.notebook_repr_html', False)

# %matplotlib inline
plt.style.use('seaborn-white')
# Out:
# C:\Users\kevjy\Anaconda\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
np.random.seed(1)
X = np.random.randn(100)
y = np.random.randn(100)
y = X - (2 *X**2) + np.random.randn(100)

# %% [markdown]
# Here we have that n=100 and p=2, the model used is
#
# Y=X−2X2+ε.
#
# where $\epsilon$ is some noise

# %%
plt.scatter(X,y)

# %%
np.random.seed(10)
x = np.random.randn(100)
y = np.random.randn(100)
y = x - (2 *x**2) + np.random.randn(100)
df = pd.DataFrame(np.c_[x,y], columns = ['x','y'])

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model as sklm
import sklearn.model_selection as skms
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures

def linear_leave_one_out(self, degree=1):
        """
        Bootstrap for Leave One Out Cross Validation of Linear Regression.
        :param int degree: the degree of the polynomial features to generate
        """
        loo = skms.LeaveOneOut()
        model = make_pipeline(PolynomialFeatures(degree),
                              sklm.LinearRegression())
        scores = skms.cross_val_score(model, self.x.reshape(-1,1), self.y,
                                      scoring='neg_mean_squared_error', cv=loo)
        print 'Leave One Out Mean Square Error: ' + str(scores.mean() * -1) + '+/- ' + str(scores.std())
              

for deg in range(1, 5):
    print('{}\nPolynomial Model Degree: {}\n'.format('*' * 80, deg))
    linear_leave_one_out(df,degree=deg)
# Out:
# ********************************************************************************
# Polynomial Model Degree: 1
#
# Leave One Out Mean Square Error: 9.69308853773+/- 21.9362781971
# ********************************************************************************
# Polynomial Model Degree: 2
#
# Leave One Out Mean Square Error: 0.882449703088+/- 1.15736033227
# ********************************************************************************
# Polynomial Model Degree: 3
#
# Leave One Out Mean Square Error: 0.902082122872+/- 1.23793341477
# ********************************************************************************
# Polynomial Model Degree: 4
#
# Leave One Out Mean Square Error: 0.92560396807+/- 1.26852226393

# %%
np.random.seed(105)

def linear_leave_one_out(self, degree=1):
        """
        Bootstrap for Leave One Out Cross Validation of Linear Regression.
        :param int degree: the degree of the polynomial features to generate
        """
        loo = skms.LeaveOneOut()
        model = make_pipeline(PolynomialFeatures(degree),
                              sklm.LinearRegression())
        scores = skms.cross_val_score(model, self.x.reshape(-1,1), self.y,
                                      scoring='neg_mean_squared_error', cv=loo)
        print 'Leave One Out Mean Square Error: ' + str(scores.mean() * -1) + '+/- ' + str(scores.std())
              

for deg in range(1, 5):
    print('{}\nPolynomial Model Degree: {}\n'.format('*' * 80, deg))
    linear_leave_one_out(df,degree=deg)
# Out:
# ********************************************************************************
# Polynomial Model Degree: 1
#
# Leave One Out Mean Square Error: 9.69308853773+/- 21.9362781971
# ********************************************************************************
# Polynomial Model Degree: 2
#
# Leave One Out Mean Square Error: 0.882449703088+/- 1.15736033227
# ********************************************************************************
# Polynomial Model Degree: 3
#
# Leave One Out Mean Square Error: 0.902082122872+/- 1.23793341477
# ********************************************************************************
# Polynomial Model Degree: 4
#
# Leave One Out Mean Square Error: 0.92560396807+/- 1.26852226393

# %% [markdown]
# ### 2(d)
# Running the same model twice with different seed yields the same result.
# This is because LOOCV has a k = n where the data is trained n times to predict one point.
# As a result, retraining the model with a different seed would still yield the same result since every kfold combination is used in this training model

# %% [markdown]
# ### 2(e)
# The qudratic model had the lowest mean square error. This is to be expected since the scatter plot of X,Y appears to be a parabola (quadratic function)

# %% [markdown]
# ## 2(f)

# %%
df = pd.DataFrame(np.array([np.ones(len(x)), x, x**2, x**3, x**4, y]).T,
                      columns=['b0', 'x', 'x2', 'x3', 'x4', 'y'])

df.head()
# Out:
#     b0         x        x2            x3            x4         y
# 0  1.0  1.331587  1.773123  2.361066e+00  3.143964e+00 -2.081521
# 1  1.0  0.715279  0.511624  3.659539e-01  2.617591e-01  0.894775
# 2  1.0 -1.545400  2.388262 -3.690821e+00  5.703796e+00 -7.346677
# 3  1.0 -0.008384  0.000070 -5.892919e-07  4.940535e-09  0.151875
# 4  1.0  0.621336  0.386058  2.398720e-01  1.490411e-01 -1.281256

# %%
y = df['y']
X = sm.add_constant(df[['x','x2','x3','x4']])
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     242.3
# Date:                Mon, 09 Oct 2017   Prob (F-statistic):           6.43e-49
# Time:                        14:57:17   Log-Likelihood:                -131.82
# No. Observations:                 100   AIC:                             273.6
# Df Residuals:                      95   BIC:                             286.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0182      0.132      0.138      0.891      -0.244       0.281
# ...

# %% [markdown]
# Taking a look at the P-values above. The only values with statstical significance (P-Values less than 0.5) are X and X^2.
#
# This is to be expected since, the quadratic fit has the lowest errors.
